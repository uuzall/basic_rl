# %%
import gymnasium as gym
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count
import numpy as np 
import stable_baselines3 as sb 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision

from tqdm import tqdm, trange
import wandb

# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
	from IPython import display

plt.ion()

# if GPU is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
env = gym.make('Pusher-v4')
model = sb.PPO('MlpPolicy', env, verbose=1, learning_rate=2.5e-4)
timesteps = 1000000
model.learn(total_timesteps=timesteps)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -123     |
# | time/              |          |
# |    fps             | 463      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -122        |
# | time/                   |             |
# |    fps                  | 378         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010547801 |
# |    clip_fraction        | 0.0978      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.92       |
# |    explained_variance   | -0.04       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 38.3        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.996       |
# |    value_loss           | 191         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -121        |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007941496 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.86       |
# |    explained_variance   | -0.0241     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 47.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.984       |
# |    value_loss           | 162         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 4           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010690869 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.78       |
# |    explained_variance   | -0.00139    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 41.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 0.974       |
# |    value_loss           | 156         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -119        |
# | time/                   |             |
# |    fps                  | 349         |
# |    iterations           | 5           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012194328 |
# |    clip_fraction        | 0.0993      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.7        |
# |    explained_variance   | 0.00104     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 42.5        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.963       |
# |    value_loss           | 130         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -118        |
# | time/                   |             |
# |    fps                  | 348         |
# |    iterations           | 6           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014385968 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.6        |
# |    explained_variance   | -0.000611   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 28.6        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0208     |
# |    std                  | 0.946       |
# |    value_loss           | 106         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 347         |
# |    iterations           | 7           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010466976 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.52       |
# |    explained_variance   | -0.00301    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 30.1        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0162     |
# |    std                  | 0.94        |
# |    value_loss           | 98.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 347         |
# |    iterations           | 8           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011387166 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.44       |
# |    explained_variance   | -0.000947   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14.5        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.926       |
# |    value_loss           | 61.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -111         |
# | time/                   |              |
# |    fps                  | 346          |
# |    iterations           | 9            |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0136878155 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -9.33        |
# |    explained_variance   | 0.000412     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 13.1         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0206      |
# |    std                  | 0.911        |
# |    value_loss           | 54.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 10          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.014367936 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.16       |
# |    explained_variance   | -6.06e-05   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7           |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.884       |
# |    value_loss           | 34.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 11          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014399954 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.98       |
# |    explained_variance   | 0.000108    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.97        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0222     |
# |    std                  | 0.866       |
# |    value_loss           | 23.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 12          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.019550465 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.82       |
# |    explained_variance   | -0.000302   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.82        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0202     |
# |    std                  | 0.841       |
# |    value_loss           | 16.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -101       |
# | time/                   |            |
# |    fps                  | 345        |
# |    iterations           | 13         |
# |    time_elapsed         | 77         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01719762 |
# |    clip_fraction        | 0.111      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.64      |
# |    explained_variance   | -0.00146   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 1.34       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0145    |
# |    std                  | 0.822      |
# |    value_loss           | 11.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -99.1      |
# | time/                   |            |
# |    fps                  | 345        |
# |    iterations           | 14         |
# |    time_elapsed         | 82         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01812771 |
# |    clip_fraction        | 0.152      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.47      |
# |    explained_variance   | 0.000148   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 1.5        |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0177    |
# |    std                  | 0.798      |
# |    value_loss           | 6.42       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -96.6       |
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 15          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.015534557 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | -0.000532   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.07        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.78        |
# |    value_loss           | 4.52        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -94.3       |
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 16          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.016167551 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.08       |
# |    explained_variance   | 0.000898    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.83        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0248     |
# |    std                  | 0.758       |
# |    value_loss           | 2.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -91.8       |
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 17          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.014558659 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.9        |
# |    explained_variance   | -0.184      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.28        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0235     |
# |    std                  | 0.742       |
# |    value_loss           | 1.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -89.8       |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 18          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.013955561 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.73       |
# |    explained_variance   | 0.467       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.569       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0236     |
# |    std                  | 0.722       |
# |    value_loss           | 1.24        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -86.3      |
# | time/                   |            |
# |    fps                  | 342        |
# |    iterations           | 19         |
# |    time_elapsed         | 113        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.01366847 |
# |    clip_fraction        | 0.163      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.56      |
# |    explained_variance   | 0.528      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.375      |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0268    |
# |    std                  | 0.707      |
# |    value_loss           | 1.19       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -84         |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 20          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.015516008 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.42       |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.427       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0288     |
# |    std                  | 0.694       |
# |    value_loss           | 1.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -81.9       |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 21          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.012861937 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.28       |
# |    explained_variance   | 0.522       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.43        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0237     |
# |    std                  | 0.678       |
# |    value_loss           | 1.41        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -79.8       |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 22          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.014785619 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.13       |
# |    explained_variance   | 0.656       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.243       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0281     |
# |    std                  | 0.665       |
# |    value_loss           | 0.796       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -77.8      |
# | time/                   |            |
# |    fps                  | 340        |
# |    iterations           | 23         |
# |    time_elapsed         | 138        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01388051 |
# |    clip_fraction        | 0.171      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7         |
# |    explained_variance   | 0.384      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.291      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0271    |
# |    std                  | 0.652      |
# |    value_loss           | 0.989      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -76.1       |
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 24          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.013704395 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.84       |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.198       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0226     |
# |    std                  | 0.637       |
# |    value_loss           | 0.606       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -74.9       |
# | time/                   |             |
# |    fps                  | 339         |
# |    iterations           | 25          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.013932211 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.71       |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.23        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0232     |
# |    std                  | 0.627       |
# |    value_loss           | 0.66        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -73.1       |
# | time/                   |             |
# |    fps                  | 339         |
# |    iterations           | 26          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.012548347 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.6        |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.323       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0211     |
# |    std                  | 0.617       |
# |    value_loss           | 0.896       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -71.8       |
# | time/                   |             |
# |    fps                  | 339         |
# |    iterations           | 27          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.013502119 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.51       |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.248       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.022      |
# |    std                  | 0.61        |
# |    value_loss           | 0.86        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -70.8       |
# | time/                   |             |
# |    fps                  | 339         |
# |    iterations           | 28          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.013165738 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.42       |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.467       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 0.602       |
# |    value_loss           | 1.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -69.9       |
# | time/                   |             |
# |    fps                  | 338         |
# |    iterations           | 29          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.013211511 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.34       |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.243       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0213     |
# |    std                  | 0.595       |
# |    value_loss           | 1.35        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -69.3       |
# | time/                   |             |
# |    fps                  | 339         |
# |    iterations           | 30          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.014835234 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.23       |
# |    explained_variance   | 0.775       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.279       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0252     |
# |    std                  | 0.584       |
# |    value_loss           | 0.942       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -68.7       |
# | time/                   |             |
# |    fps                  | 338         |
# |    iterations           | 31          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.014327535 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.09       |
# |    explained_variance   | 0.862       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.417       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0243     |
# |    std                  | 0.573       |
# |    value_loss           | 0.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -67.8       |
# | time/                   |             |
# |    fps                  | 338         |
# |    iterations           | 32          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010943655 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6          |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.244       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.568       |
# |    value_loss           | 0.69        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -67         |
# | time/                   |             |
# |    fps                  | 338         |
# |    iterations           | 33          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.016705366 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.9        |
# |    explained_variance   | 0.841       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.24        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0285     |
# |    std                  | 0.558       |
# |    value_loss           | 0.682       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -66.5      |
# | time/                   |            |
# |    fps                  | 338        |
# |    iterations           | 34         |
# |    time_elapsed         | 205        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.01293142 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.78      |
# |    explained_variance   | 0.77       |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.208      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0194    |
# |    std                  | 0.549      |
# |    value_loss           | 0.745      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -65.7       |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 35          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.013561746 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.538       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 0.54        |
# |    value_loss           | 1.35        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -64.7       |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 36          |
# |    time_elapsed         | 218         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.012272775 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.57       |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.206       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.016      |
# |    std                  | 0.533       |
# |    value_loss           | 0.641       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -63.9       |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 37          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.012668343 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.47       |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.348       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.526       |
# |    value_loss           | 0.855       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -62.6       |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 38          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.012522927 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.37       |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.41        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.518       |
# |    value_loss           | 1.31        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -61.6       |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 39          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.015616986 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.29       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.246       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0218     |
# |    std                  | 0.513       |
# |    value_loss           | 0.504       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -60.2       |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 40          |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012386881 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.21       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.252       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 0.507       |
# |    value_loss           | 0.733       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -59.7       |
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 41          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.015403222 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.1        |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.2         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0217     |
# |    std                  | 0.498       |
# |    value_loss           | 0.61        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -59.5        |
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 42           |
# |    time_elapsed         | 255          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0137992855 |
# |    clip_fraction        | 0.159        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.01        |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.286        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0187      |
# |    std                  | 0.493        |
# |    value_loss           | 0.54         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -59         |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 43          |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.014360261 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.93       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.212       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0207     |
# |    std                  | 0.487       |
# |    value_loss           | 0.604       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -58.2       |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 44          |
# |    time_elapsed         | 268         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.014256894 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.82       |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.203       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.479       |
# |    value_loss           | 0.725       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -57.7       |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 45          |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.013830988 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.74       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.256       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.475       |
# |    value_loss           | 0.659       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -56.7       |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 46          |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.015667638 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.65       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.311       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.467       |
# |    value_loss           | 0.734       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -55.6       |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 47          |
# |    time_elapsed         | 286         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.012752021 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.56       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.203       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0171     |
# |    std                  | 0.463       |
# |    value_loss           | 0.601       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -55.3       |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 48          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.013098358 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.48       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.181       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 0.456       |
# |    value_loss           | 0.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -54.6       |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 49          |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.011221029 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.38       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.323       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.451       |
# |    value_loss           | 0.768       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -53.9       |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 50          |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.015589768 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.178       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.021      |
# |    std                  | 0.446       |
# |    value_loss           | 0.752       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -53.2       |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 51          |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.015372618 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.353       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 0.441       |
# |    value_loss           | 0.8         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -53        |
# | time/                   |            |
# |    fps                  | 335        |
# |    iterations           | 52         |
# |    time_elapsed         | 317        |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.01611213 |
# |    clip_fraction        | 0.193      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.15      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.223      |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.0183    |
# |    std                  | 0.437      |
# |    value_loss           | 0.849      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -52.4       |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 53          |
# |    time_elapsed         | 323         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.014793098 |
# |    clip_fraction        | 0.187       |
# ...
# |    entropy_loss         | 5.43        |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0758      |
# |    n_updates            | 4710        |
# |    policy_gradient_loss | -0.00215    |
# |    std                  | 0.112       |
# |    value_loss           | 0.285       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -25.5       |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 473         |
# |    time_elapsed         | 2933        |
# |    total_timesteps      | 968704      |
# | train/                  |             |
# |    approx_kl            | 0.053827036 |
# |    clip_fraction        | 0.407       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.48        |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0741      |
# |    n_updates            | 4720        |
# |    policy_gradient_loss | 0.00338     |
# |    std                  | 0.111       |
# |    value_loss           | 0.114       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -25.1      |
# | time/                   |            |
# |    fps                  | 330        |
# |    iterations           | 474        |
# |    time_elapsed         | 2939       |
# |    total_timesteps      | 970752     |
# | train/                  |            |
# |    approx_kl            | 0.05401776 |
# |    clip_fraction        | 0.411      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.49       |
# |    explained_variance   | 0.923      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.159      |
# |    n_updates            | 4730       |
# |    policy_gradient_loss | -0.000719  |
# |    std                  | 0.111      |
# |    value_loss           | 0.558      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -25.8      |
# | time/                   |            |
# |    fps                  | 330        |
# |    iterations           | 475        |
# |    time_elapsed         | 2946       |
# |    total_timesteps      | 972800     |
# | train/                  |            |
# |    approx_kl            | 0.05454586 |
# |    clip_fraction        | 0.367      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.51       |
# |    explained_variance   | 0.935      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.264      |
# |    n_updates            | 4740       |
# |    policy_gradient_loss | -0.00439   |
# |    std                  | 0.11       |
# |    value_loss           | 0.659      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -26.3      |
# | time/                   |            |
# |    fps                  | 330        |
# |    iterations           | 476        |
# |    time_elapsed         | 2952       |
# |    total_timesteps      | 974848     |
# | train/                  |            |
# |    approx_kl            | 0.04168041 |
# |    clip_fraction        | 0.331      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.54       |
# |    explained_variance   | 0.949      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.319      |
# |    n_updates            | 4750       |
# |    policy_gradient_loss | -0.00495   |
# |    std                  | 0.11       |
# |    value_loss           | 1.21       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -27.6       |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 477         |
# |    time_elapsed         | 2958        |
# |    total_timesteps      | 976896      |
# | train/                  |             |
# |    approx_kl            | 0.035944466 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.54        |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.478       |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | -0.000315   |
# |    std                  | 0.11        |
# |    value_loss           | 1.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -28.3       |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 478         |
# |    time_elapsed         | 2964        |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.036012523 |
# |    clip_fraction        | 0.336       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.52        |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.03        |
# |    n_updates            | 4770        |
# |    policy_gradient_loss | -0.00382    |
# |    std                  | 0.11        |
# |    value_loss           | 1.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -28.7       |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 479         |
# |    time_elapsed         | 2970        |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.052697353 |
# |    clip_fraction        | 0.38        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.53        |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.245       |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.00555    |
# |    std                  | 0.11        |
# |    value_loss           | 0.897       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -28.4      |
# | time/                   |            |
# |    fps                  | 330        |
# |    iterations           | 480        |
# |    time_elapsed         | 2977       |
# |    total_timesteps      | 983040     |
# | train/                  |            |
# |    approx_kl            | 0.03976881 |
# |    clip_fraction        | 0.366      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.52       |
# |    explained_variance   | 0.969      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.283      |
# |    n_updates            | 4790       |
# |    policy_gradient_loss | -0.000554  |
# |    std                  | 0.11       |
# |    value_loss           | 1.08       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -28.7       |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 481         |
# |    time_elapsed         | 2983        |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.042371362 |
# |    clip_fraction        | 0.367       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.52        |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.208       |
# |    n_updates            | 4800        |
# |    policy_gradient_loss | -0.002      |
# |    std                  | 0.11        |
# |    value_loss           | 0.574       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -27.8       |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 482         |
# |    time_elapsed         | 2989        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.033471476 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.54        |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.303       |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | 0.00187     |
# |    std                  | 0.11        |
# |    value_loss           | 1.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -27         |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 483         |
# |    time_elapsed         | 2995        |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.043083835 |
# |    clip_fraction        | 0.412       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.55        |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.217       |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | 0.000483    |
# |    std                  | 0.11        |
# |    value_loss           | 0.648       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -26.4       |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 484         |
# |    time_elapsed         | 3001        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.059385564 |
# |    clip_fraction        | 0.413       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.54        |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0819      |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | 0.00136     |
# |    std                  | 0.11        |
# |    value_loss           | 0.226       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -25.8       |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 485         |
# |    time_elapsed         | 3007        |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.051711068 |
# |    clip_fraction        | 0.413       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.52        |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0583      |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.000154   |
# |    std                  | 0.111       |
# |    value_loss           | 0.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -24.9       |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 486         |
# |    time_elapsed         | 3014        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.036272146 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.53        |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0122     |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | 0.00335     |
# |    std                  | 0.11        |
# |    value_loss           | 0.0419      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -24.4       |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 487         |
# |    time_elapsed         | 3020        |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.043620802 |
# |    clip_fraction        | 0.399       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.55        |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0494      |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | -0.000398   |
# |    std                  | 0.11        |
# |    value_loss           | 0.261       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -24.4       |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 488         |
# |    time_elapsed         | 3026        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.053734064 |
# |    clip_fraction        | 0.408       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 5.56        |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.009      |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.00283    |
# |    std                  | 0.11        |
# |    value_loss           | 0.066       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -24.6      |
# | time/                   |            |
# |    fps                  | 330        |
# |    iterations           | 489        |
# |    time_elapsed         | 3032       |
# |    total_timesteps      | 1001472    |
# | train/                  |            |
# |    approx_kl            | 0.05216298 |
# |    clip_fraction        | 0.38       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.55       |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.0343     |
# |    n_updates            | 4880       |
# |    policy_gradient_loss | -0.00848   |
# |    std                  | 0.11       |
# |    value_loss           | 0.156      |
# ----------------------------------------

# %%
model.save(f'models/pusher_ppo/sb_{timesteps}')
